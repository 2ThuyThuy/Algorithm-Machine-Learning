# %%
import numpy as np
import pandas as pd

import glob 
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
import IPython.display as ipd
import wave 
# Load use scipy
from scipy.io import wavfile
import librosa
import librosa.display

# %%
INPUT_DIR = "../JKspeech"
PROBLEM_DIR = "../sample_Q_202205/sample_Q_E01/problem1.wav"
normal_file_1 = INPUT_DIR + "/E01.wav"
normal_file_2 = INPUT_DIR + "/E02.wav"
normal_file_3 = INPUT_DIR + "/E03.wav"

# %%
display(ipd.Audio(normal_file_1))
display(ipd.Audio(normal_file_2))
display(ipd.Audio(normal_file_3))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(PROBLEM_DIR)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rate_1, data_1 = wavfile.read(normal_file_1)
print("Sampling (frame) rate = ", rate_1)
print("Total samples (frames) = ", data_1.shape)
print(data_1)
# Out:
# Sampling (frame) rate =  48000
# Total samples (frames) =  (269473,)
# [ 38  47  71 ... -14 -13 -17]

# %%
rate_2, data_2 = wavfile.read(normal_file_2)
print("Sampling (frame) rate = ", rate_2)
print("Total samples (frames) = ", data_2.shape)
print(data_2)
# Out:
# Sampling (frame) rate =  48000
# Total samples (frames) =  (278344,)
# [ 0 -1  1 ... -2 -3 -3]

# %%
rate_3, data_3 = wavfile.read(normal_file_3)
print("Sampling (frame) rate = ", rate_3)
print("Total samples (frames) = ", data_3.shape)
print(data_3)
# Out:
# Sampling (frame) rate =  48000
# Total samples (frames) =  (226816,)
# [-1 -1  4 ...  3  2  1]

# %%
# plot wave by audio frames
plt.figure(figsize=(16, 3))
plt.plot(data_1, '-', alpha=0.7)
plt.plot(data_2, '-', alpha=0.7)
plt.plot(data_3, '-', alpha=0.7)

# %%
# plot wave by audio frames
plt.figure(figsize=(16, 3))
plt.title('')
plt.plot(data_2, '-', alpha=0.2)
plt.plot(data_3, '-', alpha=0.3)
plt.plot(data_1, '-', alpha=1)

# %%
rate_problem, data_problem = wavfile.read(PROBLEM_DIR)
print("Sampling (frame) rate = ", rate_problem)
print("Total samples (frames) = ", data_problem.shape)
print(data_problem)
# Out:
# Sampling (frame) rate =  48000
# Total samples (frames) =  (96000,)
# [   37    45    76 ... -1104    77   684]

# %%
# plot wave by audio frames
plt.figure(figsize=(16, 3))
plt.plot(data_problem, '-', );
